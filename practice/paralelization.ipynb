# %%
from IPython.display import Image, display
from langgraph.graph import StateGraph, START, END
import os
import config_data as config
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from typing_extensions import TypedDict

# 1.初始化LLM
load_dotenv()
llm = init_chat_model(
    model=config.chat_model_name,
    model_provider=config.chat_model_provider,
    base_url = os.getenv("DASHSCOPE_BASE_URL"),
    api_key = os.getenv("DASHSCOPE_API_KEY"),
    temperature=0.0,  # 🔥 必须 0
)

# 2. Define Graph state
class State(TypedDict):
    topic: str
    joke: str
    story: str
    poem: str
    combined_output: str

# 3. Define nodes
def call_llm_1(state: State):
    """First LLM call to generate initial joke"""
    msg = llm.invoke(f"Write a joke about {state['topic']}")
    return {"joke": msg.content}

def call_llm_2(state: State):
    """Second LLM call to generate story"""
    msg = llm.invoke(f"Write a story about {state['topic']}")
    return {"story": msg.content}

def call_llm_3(state: State):
    """Third LLM call to generate poem"""
    msg = llm.invoke(f"Write a poem about {state['topic']}")
    return {"poem": msg.content}

def aggregator(state: State):
    """Combine the joke, story and poem into a single output"""
    combined = f"Here's a story, joke, and poem about {state['topic']}!\n\n"
    combined += f"STORY:\n{state['story']}\n\n"
    combined += f"JOKE:\n{state['joke']}\n\n"
    combined += f"POEM:\n{state['poem']}"
    return {"combined_output": combined}

# Build workflow
parallel_builder = StateGraph(State)

# Add nodes
parallel_builder.add_node("call_llm_1", call_llm_1)
parallel_builder.add_node("call_llm_2", call_llm_2)
parallel_builder.add_node("call_llm_3", call_llm_3)
parallel_builder.add_node("aggregator", aggregator)

# Add nodes
parallel_builder.add_edge(START, "call_llm_1")
parallel_builder.add_edge(START, "call_llm_2")
parallel_builder.add_edge(START, "call_llm_3")
parallel_builder.add_edge("call_llm_1", "aggregator")
parallel_builder.add_edge("call_llm_2", "aggregator")
parallel_builder.add_edge("call_llm_3", "aggregator")
parallel_builder.add_edge("aggregator", END)
parallel_workflow = parallel_builder.compile()

display(Image(parallel_workflow.get_graph().draw_mermaid_png()))

state = parallel_workflow.invoke({"topic": "dogs"})
print(state["combined_output"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/PycharmProjects/langgraph-demo/.venv/lib/python3.13/site-packages/langgraph/pregel/main.py:2936, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2935     loop.output_writes(task.id, task.writes, cached=True)
# -> 2936 for _ in runner.tick(
#    2937     [t for t in loop.tasks.values() if not t.writes],
#    2938     timeout=self.step_timeout,
#    2939     get_waiter=get_waiter,
#    2940     schedule_task=loop.accept_push,
#    2941 ):
#    2942     # emit output
#    2943     yield from _output(
#    2944         stream_mode,
#    2945         print_mode,
#    (...)   2951         _state_mapper,
#    2952     )
#
# File ~/PycharmProjects/langgraph-demo/.venv/lib/python3.13/site-packages/langgraph/pregel/_runner.py:283, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     282 while len(futures) > (1 if get_waiter is not None else 0):
# --> 283     done, inflight = concurrent.futures.wait(
#     284         futures,
#     285         return_when=concurrent.futures.FIRST_COMPLETED,
#     286         timeout=(max(0, end_time - time.monotonic()) if end_time else None),
#     287     )
#     288     if not done:
#
# File ~/.local/share/uv/python/cpython-3.13.13-macos-aarch64-none/lib/python3.13/concurrent/futures/_base.py:305, in wait(fs, timeout, return_when)
#     303     waiter = _create_and_install_waiters(fs, return_when)
# --> 305 waiter.event.wait(timeout)
#     306 for f in fs:
#
# File ~/.local/share/uv/python/cpython-3.13.13-macos-aarch64-none/lib/python3.13/threading.py:660, in Event.wait(self, timeout)
#     659 if not signaled:
# --> 660     signaled = self._cond.wait(timeout)
#     661 return signaled
#
# File ~/.local/share/uv/python/cpython-3.13.13-macos-aarch64-none/lib/python3.13/threading.py:359, in Condition.wait(self, timeout)
#     358 if timeout is None:
# --> 359     waiter.acquire()
#     360     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 72
#      68 parallel_workflow = parallel_builder.compile()
#      69
#      70 display(Image(parallel_workflow.get_graph().draw_mermaid_png()))
#      71
# ---> 72 state = parallel_workflow.invoke({"topic": "dogs"})
#      73 print(state["combined_output"])
#
# File ~/PycharmProjects/langgraph-demo/.venv/lib/python3.13/site-packages/langgraph/pregel/main.py:3880, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3877             chunks.append(chunk)
#    3878 else:
#    3879     # v1: collect interrupts from updates stream
# -> 3880     for chunk in self.stream(
#    3881         input,
#    3882         config,
#    3883         context=context,
#    3884         stream_mode=(
#    3885             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3886         ),
#    3887         print_mode=print_mode,
#    3888         output_keys=output_keys,
#    3889         interrupt_before=interrupt_before,
#    3890         interrupt_after=interrupt_after,
#    3891         durability=durability,
#    3892         control=control,
#    3893         **kwargs,
#    3894     ):
#    3895         if stream_mode == "values":
#    3896             if len(chunk) == 2:
#
# File ~/PycharmProjects/langgraph-demo/.venv/lib/python3.13/site-packages/langgraph/pregel/main.py:2868, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2863         else:
#    2864             graph_callback_manager.on_interrupt(
#    2865                 replace(event, run_id=graph_callback_manager.run_id)
#    2866             )
# -> 2868 with SyncPregelLoop(
#    2869     input,
#    2870     stream=StreamProtocol(stream.put, stream_modes),
#    2871     config=config,
#    2872     store=store,
#    2873     cache=cache,
#    2874     checkpointer=checkpointer,
#    2875     nodes=self.nodes,
#    2876     specs=self.channels,
#    2877     output_keys=output_keys,
#    2878     input_keys=self.input_channels,
#    2879     stream_keys=self.stream_channels_asis,
#    2880     interrupt_before=interrupt_before_,
#    2881     interrupt_after=interrupt_after_,
#    2882     manager=run_manager,
#    2883     durability=durability_,
#    2884     trigger_to_nodes=self.trigger_to_nodes,
#    2885     migrate_checkpoint=self._migrate_checkpoint,
#    2886     retry_policy=self.retry_policy,
#    2887     cache_policy=self.cache_policy,
#    2888     has_graph_lifecycle_callbacks=bool(graph_callback_manager.handlers),
#    2889 ) as loop:
#    2890     emit_graph_lifecycle_events(loop)
#    2891     # create runner
#
# File ~/PycharmProjects/langgraph-demo/.venv/lib/python3.13/site-packages/langgraph/pregel/_loop.py:1686, in SyncPregelLoop.__exit__(self, exc_type, exc_value, traceback)
#    1679 def __exit__(
#    1680     self,
#    1681     exc_type: type[BaseException] | None,
#    (...)   1684 ) -> bool | None:
#    1685     # unwind stack
# -> 1686     return self.stack.__exit__(exc_type, exc_value, traceback)
#
# File ~/.local/share/uv/python/cpython-3.13.13-macos-aarch64-none/lib/python3.13/contextlib.py:619, in ExitStack.__exit__(self, *exc_details)
#     615 try:
#     616     # bare "raise exc" replaces our carefully
#     617     # set-up context
#     618     fixed_ctx = exc.__context__
# --> 619     raise exc
#     620 except BaseException:
#     621     exc.__context__ = fixed_ctx
#
# File ~/.local/share/uv/python/cpython-3.13.13-macos-aarch64-none/lib/python3.13/contextlib.py:604, in ExitStack.__exit__(self, *exc_details)
#     602 else:
#     603     exc_details = type(exc), exc, exc.__traceback__
# --> 604 if cb(*exc_details):
#     605     suppressed_exc = True
#     606     pending_raise = False
#
# File ~/PycharmProjects/langgraph-demo/.venv/lib/python3.13/site-packages/langgraph/pregel/_executor.py:107, in BackgroundExecutor.__exit__(self, exc_type, exc_value, traceback)
#     105 # wait for all tasks to finish
#     106 if pending := {t for t in tasks if not t.done()}:
# --> 107     concurrent.futures.wait(pending)
#     108 # shutdown the executor
#     109 self.stack.__exit__(exc_type, exc_value, traceback)
#
# File ~/.local/share/uv/python/cpython-3.13.13-macos-aarch64-none/lib/python3.13/concurrent/futures/_base.py:305, in wait(fs, timeout, return_when)
#     301         return DoneAndNotDoneFutures(done, not_done)
#     303     waiter = _create_and_install_waiters(fs, return_when)
# --> 305 waiter.event.wait(timeout)
#     306 for f in fs:
#     307     with f._condition:
#
# File ~/.local/share/uv/python/cpython-3.13.13-macos-aarch64-none/lib/python3.13/threading.py:660, in Event.wait(self, timeout)
#     658 signaled = self._flag
#     659 if not signaled:
# --> 660     signaled = self._cond.wait(timeout)
#     661 return signaled
#
# File ~/.local/share/uv/python/cpython-3.13.13-macos-aarch64-none/lib/python3.13/threading.py:359, in Condition.wait(self, timeout)
#     357 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     358     if timeout is None:
# --> 359         waiter.acquire()
#     360         gotit = True
#     361     else:
#
# KeyboardInterrupt:
